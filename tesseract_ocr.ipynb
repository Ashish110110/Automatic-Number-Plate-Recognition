# %%
import pytesseract
import os.path

# %%
from PIL import Image

# %%
image_dir = "enter directory path where cropped licence plate images are saved"

# %%
file_name = "Cars261_png.rf.97efb9454753ec7417329cb6abd13df6.jpg"

# %%
image_path = os.path.join(image_dir, file_name)

# %% [markdown]
# **Perform OCR**

# %%
img = Image.open(image_path)
pytesseract.pytesseract.tesseract_cmd = r'Path\to\Tesseract-OCR\tesseract'
text = pytesseract.image_to_string(image_path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=405x128>

# %%
text = text.replace("\n", '')

# %%
text
# Out:
# '“TSOBER 1643'
